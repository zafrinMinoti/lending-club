# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# Functions
def whatis(feature):
    return(df_doc.loc[feature].Description)

# %%
# Reading data
df = pd.read_csv("C:/Users/zminoti/Documents/Kaggle/LendingClub/data/lending-club-loan-data/loan.csv")

df_doc = pd.read_excel("C:/Users/zminoti/Documents/Kaggle/LendingClub/data/lending-club-loan-data/LCDataDictionary.xlsx",
                       sheet_name='LoanStats', index_col=0)

df_browseNotes = pd.read_excel("C:/Users/zminoti/Documents/Kaggle/LendingClub/data/lending-club-loan-data/LCDataDictionary.xlsx",
                       sheet_name='browseNotes')
df_rejectStats = pd.read_excel("C:/Users/zminoti/Documents/Kaggle/LendingClub/data/lending-club-loan-data/LCDataDictionary.xlsx",
                       sheet_name='RejectStats')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.size
# Out:
# 65666046

# %%
with pd.option_context("display.max_rows", 1000):
    display(df_doc)
# Out:
#                                                                    Description
# LoanStatNew
# addr_state                   The state provided by the borrower in the loan...
# annual_inc                   The self-reported annual income provided by th...
# annual_inc_joint             The combined self-reported annual income provi...
# application_type             Indicates whether the loan is an individual ap...
# collection_recovery_fee                         post charge off collection fee
# collections_12_mths_ex_med   Number of collections in 12 months excluding m...
# delinq_2yrs                  The number of 30+ days past-due incidences of ...
# desc                                 Loan description provided by the borrower
# dti                          A ratio calculated using the borrower’s total ...
# dti_joint                    A ratio calculated using the co-borrowers' tot...
# earliest_cr_line             The month the borrower's earliest reported cre...
# ...

# %%
for i in df_doc.index:
    print(i, '\t', whatis(i))
# Out:
# addr_state 	 The state provided by the borrower in the loan application
# annual_inc 	 The self-reported annual income provided by the borrower during registration.
# annual_inc_joint 	 The combined self-reported annual income provided by the co-borrowers during registration
# application_type 	 Indicates whether the loan is an individual application or a joint application with two co-borrowers
# collection_recovery_fee 	 post charge off collection fee
# collections_12_mths_ex_med 	 Number of collections in 12 months excluding medical collections
# delinq_2yrs 	 The number of 30+ days past-due incidences of delinquency in the borrower's credit file for the past 2 years
# desc 	 Loan description provided by the borrower
# dti 	 A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.
# ...

# %%
whatis('last_pymnt_d')
# Out:
# 'Last month payment was received'

# %%
df.last_pymnt_d.unique().size
# Out:
# 99

# %%
import seaborn as sns

# %%
sns.heatmap(df[df.columns[1:]].corr(), 
           cmap='bwr', square=True, linewidths=0.5)

# %%
df[df.columns[1:]].corr()['LoanAmount'][:]
# Out:
#                              member_id  loan_amnt  funded_amnt  \
# member_id                     1.000000   0.064461     0.066754
# loan_amnt                     0.064461   1.000000     0.999263
# funded_amnt                   0.066754   0.999263     1.000000
# funded_amnt_inv               0.072308   0.997115     0.998025
# int_rate                     -0.142205   0.145023     0.145160
# installment                   0.026036   0.944977     0.946005
# annual_inc                    0.034146   0.332698     0.332466
# dti                           0.067824   0.020675     0.021075
# delinq_2yrs                   0.049904  -0.000159     0.000151
# inq_last_6mths               -0.127257  -0.034168    -0.034711
# mths_since_last_delinq       -0.008682  -0.038080    -0.038117
# mths_since_last_record       -0.158700  -0.010734    -0.010811
# open_acc                      0.088838   0.198906     0.199387
# pub_rec                       0.080788  -0.081177    -0.080836
# ...

# %%
df[df.columns[1:]].corr()['int_rate'][:].sort_values()
# Out:
# total_rev_hi_lim              -0.166119
# member_id                     -0.142205
# mths_since_rcnt_il            -0.128746
# max_bal_bc                    -0.104402
# annual_inc_joint              -0.099026
# tot_cur_bal                   -0.091408
# annual_inc                    -0.072786
# total_acc                     -0.038618
# revol_bal                     -0.035708
# mths_since_last_delinq        -0.030033
# mths_since_last_major_derog   -0.011180
# open_acc                      -0.010381
# tot_coll_amt                   0.001130
# collections_12_mths_ex_med     0.013336
# total_cu_tl                    0.020711
# mths_since_last_record         0.022485
# acc_now_delinq                 0.026478
# out_prncp_inv                  0.042529
# out_prncp                      0.042671
# open_il_6m                     0.044591
# pub_rec                        0.052156
# total_bal_il                   0.053045
# total_rec_prncp                0.054975
# ...

# %%
df.loan_status.value_counts()
# Out:
# Current                                                601779
# Fully Paid                                             207723
# Charged Off                                             45248
# Late (31-120 days)                                      11591
# Issued                                                   8460
# In Grace Period                                          6253
# Late (16-30 days)                                        2357
# Does not meet the credit policy. Status:Fully Paid       1988
# Default                                                  1219
# Does not meet the credit policy. Status:Charged Off       761
# Name: loan_status, dtype: int64

# %%
df.delinq_2yrs.value_counts()
# Out:
# 0.0     716961
# 1.0     113224
# 2.0      33551
# 3.0      11977
# 4.0       5327
# 5.0       2711
# 6.0       1471
# 7.0        784
# 8.0        461
# 9.0        284
# 10.0       192
# 11.0       121
# 12.0        89
# 13.0        64
# 14.0        45
# 15.0        28
# 16.0        17
# 18.0        11
# 17.0        10
# 19.0         8
# 22.0         3
# 21.0         2
# 26.0         2
# 20.0         2
# 30.0         1
# 39.0         1
# 27.0         1
# 29.0         1
# 24.0         1
# Name: delinq_2yrs, dtype: int64

# %%
# Distribution of loan duration (for each value in loan status)
# --> This would tell us which loans have complete information and
# which (recent) loans with current status need to be excluded from train data
df.issue_d
# Out:
# dtype('O')

# %%
# What we know for a fact:
# * Fully paid loans are good loans
# * Default and charged off loans are bad loans

# So, let's find out which features are most varrient among 
# good and bad loans defined by the obvious facts
# (look at the distributions of different features for obvious good and bad loans)
# --> features with significent/maximum differences will be selected for the model

df ['target']  = np.nan

# %%
df[df['loan_status']=='Default']
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 318      1062399    1294261    18000.0      18000.0     17975.000000
# 7620      879297    1094167    21250.0      21250.0     21003.604048
# 11759     809235    1016031     5600.0       5600.0      5600.000000
# 13439     782572     985575    15975.0      15975.0     15975.000000
# 13856     775378     977625     5000.0       5000.0      5000.000000
# 17159     720788     915272    10000.0      10000.0      9975.000000
# 18912     685965     875698    25975.0      25975.0     25854.183371
# 21228     646957     827741    16000.0      16000.0     16000.000000
# 23773     609371     781630     4200.0       4200.0      4200.000000
# 46013   10144970    9378315    12000.0      12000.0     12000.000000
# 46402   10034724   11876866     3600.0       3600.0      3600.000000
# 47145    9857791   11709653    11425.0      11425.0     11425.000000
# 47948    9846956   11698876     9000.0       9000.0      9000.000000
# ...

# %%
df['target']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
#           ..
# 887349   NaN
# 887350   NaN
# 887351   NaN
# 887352   NaN
# 887353   NaN
# 887354   NaN
# 887355   NaN
# 887356   NaN
# 887357   NaN
# 887358   NaN
# 887359   NaN
# 887360   NaN
# 887361   NaN
# 887362   NaN
# 887363   NaN
# 887364   NaN
# 887365   NaN
# 887366   NaN
# 887367   NaN
# 887368   NaN
# 887369   NaN
# 887370   NaN
# 887371   NaN
# 887372   NaN
# 887373   NaN
# 887374   NaN
# 887375   NaN
# 887376   NaN
# 887377   NaN
# 887378   NaN
# Name: target, Length: 887379, dtype: float64

# %%
df[df['loan_status']=='Default'].loc('target') = 1
# Out:
#   File "<ipython-input-118-bd59c1d2d041>", line 1
#     df[df['loan_status']=='Default'].loc('target') = 1
#                                                       ^
# SyntaxError: can't assign to function call
